// %%
%classpath add jar demoResources/beakerxTestLibrary.jar
%classpath
// Out:
// demoResources/beakerxTestLibrary.jar

// %%
%classpath add jar demoResources/beakerxTestLibrary.jar
%classpath
5+5
// Out:
// 10

// %%
%classpath
%classpath add jar demoResources/beakerxTestLibrary.jar

// %%
%classpath
