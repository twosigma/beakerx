// %% [markdown]
// # %classpath add mvn group name version

// %%
%classpath add mvn com.fasterxml.jackson.core jackson-databind 2.6.5
// Out:
// Added jars: [/tmp/beaker7995519189947448992/mvnJars/jackson-annotations.jar, /tmp/beaker7995519189947448992/mvnJars/jackson-databind.jar, /tmp/beaker7995519189947448992/mvnJars/jackson-core.jar]

// %% [markdown]
// # Gson exmaple

// %%
import com.google.gson.Gson;
// Out:
// org.codehaus.groovy.control.MultipleCompilationErrorsException: startup failed:
// script15040150004091507788998.groovy: 1: unable to resolve class com.google.gson.Gson
//  @ line 1, column 1.
//    import com.google.gson.Gson;
//    ^
//
// 1 error
//
// 	at com.twosigma.beakerx.groovy.evaluator.GroovyCodeRunner.run(GroovyCodeRunner.java:57)

// %%
%classpath add mvn com.google.code.gson gson 2.2.4
// Out:
// Added jar: [/tmp/beaker7995519189947448992/mvnJars/gson.jar]

// %%
import com.google.gson.Gson;
// Out:
// null

// %%
%classpath add mvn com.google.code.gson gson 2.2.4

import com.google.gson.Gson;
import com.google.gson.GsonBuilder;

Gson gson = new GsonBuilder().create();
gson.toJson("Hello", System.out);
// Out:
// "Hello"
// null

// %% [markdown]
// # Error handling

// %%
%classpath add mvn com.fasterxml.jackson.core1 jackson-databind 2.6.5
// Out:
// [unresolved dependency: com.fasterxml.jackson.core1#jackson-databind;2.6.5: not found]

// %%
%classpath add mvn com.fasterxml.jackson.core1 jackson-databind
// Out:
// Wrong command format, should be %classpath add mvn group name version
