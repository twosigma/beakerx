// %%
Latex('$\\alpha^2 + \\eta$')
// Out:
// groovy.lang.MissingMethodException: No signature of method: script1498572038659321410102.Latex() is applicable for argument types: (java.lang.String) values: [$\alpha^2 + \eta$]
// Possible solutions: getAt(java.lang.String), wait(), any(), grep(), wait(long), main([Ljava.lang.String;)
// 	at script1498572038659321410102.run(script1498572038659321410102.groovy:1)
// 	at com.twosigma.beakerx.groovy.evaluator.GroovyEvaluator$workerThread$MyRunnable.run(GroovyEvaluator.java:463)

// %%
HTML('<h1>Hello, world!</h1>')
// Out:
// groovy.lang.MissingMethodException: No signature of method: script1498643407703145800366.HTML() is applicable for argument types: (java.lang.String) values: [<h1>Hello, world!</h1>]
// Possible solutions: dump(), wait(), run(), run(), grep(), find()
// 	at script1498643407703145800366.run(script1498643407703145800366.groovy:1)
// 	at com.twosigma.beakerx.groovy.evaluator.GroovyEvaluator$workerThread$MyRunnable.run(GroovyEvaluator.java:463)

// %%
new MIMEContainer('text/html', '<h1> Hello World!</h1>')
// Out:
// <h1> Hello World!</h1>

// %%
new MIMEContainer(MIMEContainer.MIME.TEXT_HTML, '<h1> Hello World!</h1>')
// Out:
// <h1> Hello World!</h1>

// %%
new MIMEContainer('text/latex', '$\\alpha^2 + \\eta$')
// Out:
// $\alpha^2 + \eta$

// %%
FileLinks("./Tablesaw")
// Out:
// <a href='./Tablesaw/baseball.csv' target='_blank'>./Tablesaw/baseball.csv</a><br/><a href='./Tablesaw/tornadoes_2014.csv' target='_blank'>./Tablesaw/tornadoes_2014.csv</a><br/><a href='./Tablesaw/whiskey.csv' target='_blank'>./Tablesaw/whiskey.csv</a><br/>

// %%
FileLink("./plotDemo.ipynb")
// Out:
// <a href='./plotDemo.ipynb' target='_blank'>./plotDemo.ipynb</a><br/>

// %%
Markdown("It's **very** easy to do **bold** and *italics*:")
// Out:
// It's **very** easy to do **bold** and *italics*:

// %%
Math('F(k) = \\int_{-\\infty}^{\\infty} f(x) e^{2\\pi i k} dx')
// Out:
// $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$

// %%
IFrame('http://jupyter.org/', '100%', 400)
// Out:
// <iframe width = '100%' height= '400' src = 'http://jupyter.org/' frameborder='0' allowfullscreen> </iframe>

// %%
ScribdDocument("71048089", '100%', 400)
// Out:
// <iframe width = '100%' height= '400' src = 'https://www.scribd.com/embeds/71048089/content' frameborder='0' allowfullscreen> </iframe>

// %%
VimeoVideo("139304565",400,300)
// Out:
// <iframe width = '400' height= '300' src = 'https://player.vimeo.com/video/139304565' frameborder='0' allowfullscreen> </iframe>

// %%
YoutubeVideo("gSVvxOchT8Y")
// Out:
// <iframe width = '400' height= '300' src = 'https://www.youtube.com/embed/gSVvxOchT8Y' frameborder='0' allowfullscreen> </iframe>

// %%
Video('https://archive.org/download/Sita_Sings_the_Blues/Sita_Sings_the_Blues_small.mp4')
// Out:
// <video src='https://archive.org/download/Sita_Sings_the_Blues/Sita_Sings_the_Blues_small.mp4' controls> Your browser does not support the <code>video</code> element. </video>

// %%
SVG("https://dev.w3.org/SVG/tools/svgweb/samples/svg-files/car.svg")

// %%
SVG("./atom.svg")

// %%
Image("https://doggydollars.com/wp-content/uploads/2016/02/DoggyDollars-Retriever-300x300.jpg")

// %%
Image("./doggy.jpg")

// %%
Image("./widgetArch.png")

// %%
import java.io.File;
import com.google.common.io.ByteStreams;
import com.google.common.io.Files;

def imgFile = new File("./widgetArch.png");
def bytes = Files.toByteArray(imgFile);
Image(bytes)
