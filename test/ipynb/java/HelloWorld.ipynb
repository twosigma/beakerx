// %% [markdown]
// ### Hello world

// %%
var a = 1+1;

// %%
System.getProperty("java.version")

// %%
a+a

// %% [markdown]
// ### Cannot find symbol

// %%
stq

// %% [markdown]
// ### Magic command

// %%
%classpath add jar ../resources/jar/demo.jar

// %%
import com.example.*;

// %%
Demo demo = new Demo();
demo.getObjectTest();

// %% [markdown]
// ### Multiple lines

// %%
var a = new ArrayList();
a.add(1);
a.clone()

// %% [markdown]
// ### Autotranslation

// %%
beakerx.set("a",2)

// %%
beakerx.get("a")

// %%
%%groovy
beakerx.a
