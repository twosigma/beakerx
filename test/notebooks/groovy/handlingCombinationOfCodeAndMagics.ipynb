// %%
println(1)
%time println(221)
println(2)
  %time 1+2

// %%
println(1)
if(true){
    %time println(221)
}
println(2)
  %time 1+2

// %%
%classpath   add  jar ../../../doc/resources/jar/demo.jar

%import        com.twosigma.beakerx.widgets.integers.IntSlider

// %%
%time    println("x    y")
