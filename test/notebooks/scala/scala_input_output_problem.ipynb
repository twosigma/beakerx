// %%
println("line 1"); "first input"
// Out:
// line 1
// first input

// %%
%classpath add mvn org.scalacheck scalacheck_2.11 1.13.5
// Out:
// Added jars: [scalacheck_2.11-1.13.5.jar, scala-library-2.11.8.jar, test-interface-1.0.jar]

// %%
println("line 3"); "third input"
// Out:
// line 3
// third input

// %%
println("line 4"); "fourth input"
// Out:
// line 4
// fourth input

// %%
%classpath add mvn org.scalacheck scalacheck_2.11 1.13.5

// %%
println("line 3"); "third input"
// Out:
// line 3
// third input
